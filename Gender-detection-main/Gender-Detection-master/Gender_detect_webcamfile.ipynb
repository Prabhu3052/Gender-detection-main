# %%
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
import numpy as np
import cv2
import cvlib as cv

# %%
# Load the pre-trained gender detection model
model = load_model("C:/Users/pp684/Videos/GitHub/Gender-detection-main/Gender-detection-main/Gender-Detection-master/Model folder/gender_detection.h5", compile=False)

# %%
# Initialize the webcam
webcam = cv2.VideoCapture(0)

# %%
# Define the class labels
classes = ['man', 'woman']

# %%
# Loop to process webcam frames
while webcam.isOpened():
    # Read frame from webcam
    status, frame = webcam.read()

    if not status:
        print("Could not read frame. Exiting...")
        break

    # Detect faces in the frame
    faces, confidences = cv.detect_face(frame)

    # Process each detected face
    for idx, face in enumerate(faces):
        (startX, startY, endX, endY) = face

        # Ensure face boundaries are within the frame
        startX, startY = max(0, startX), max(0, startY)
        endX, endY = min(frame.shape[1], endX), min(frame.shape[0], endY)

        # Draw rectangle around the face
        cv2.rectangle(frame, (startX, startY), (endX, endY), (0, 255, 0), 2)

        # Crop and preprocess the face
        face_crop = frame[startY:endY, startX:endX]
        if face_crop.shape[0] < 10 or face_crop.shape[1] < 10:
            continue

        # Preprocessing: Resize, normalize, and convert channel order
        face_crop = cv2.resize(face_crop, (96, 96))
        face_crop = cv2.cvtColor(face_crop, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB if needed
        face_crop = face_crop.astype("float") / 255.0
        face_crop = img_to_array(face_crop)
        face_crop = np.expand_dims(face_crop, axis=0)

        # Predict gender
        prediction = model.predict(face_crop)[0]  # Get the prediction for the face
        man_confidence, woman_confidence = prediction[0], prediction[1]
        idx = np.argmax(prediction)  # Get the index of the class with highest confidence
        label = classes[idx]

        # Format the label
        label_text = f"{label}: {prediction[idx] * 100:.2f}%"

        # Debug: Print confidence scores
        print(f"Man confidence: {man_confidence * 100:.2f}%, Woman confidence: {woman_confidence * 100:.2f}%")

        # Position the label above the face rectangle
        label_y = startY - 10 if startY - 10 > 10 else startY + 10

        # Add label to the frame
        cv2.putText(frame, label_text, (startX, label_y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    # Display the output frame
    cv2.imshow("Gender Detection", frame)

    # Stop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
webcam.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# Man confidence: 100.00%, Woman confidence: 0.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Man confidence: 100.00%, Woman confidence: 0.01%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Man confidence: 100.00%, Woman confidence: 0.01%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 100.00%, Woman confidence: 0.01%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Man confidence: 99.99%, Woman confidence: 0.01%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Man confidence: 99.99%, Woman confidence: 0.02%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Man confidence: 99.99%, Woman confidence: 0.02%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Man confidence: 99.99%, Woman confidence: 0.03%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Man confidence: 99.99%, Woman confidence: 0.02%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Man confidence: 99.98%, Woman confidence: 0.03%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Man confidence: 99.99%, Woman confidence: 0.02%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Man confidence: 99.98%, Woman confidence: 0.04%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.99%, Woman confidence: 0.01%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.99%, Woman confidence: 0.01%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.98%, Woman confidence: 0.03%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Man confidence: 99.98%, Woman confidence: 0.04%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.98%, Woman confidence: 0.04%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 99.92%, Woman confidence: 0.12%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.92%, Woman confidence: 0.12%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.86%, Woman confidence: 0.20%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Man confidence: 99.87%, Woman confidence: 0.20%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.85%, Woman confidence: 0.24%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.75%, Woman confidence: 0.36%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.88%, Woman confidence: 0.21%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Man confidence: 99.89%, Woman confidence: 0.19%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Man confidence: 99.93%, Woman confidence: 0.13%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.94%, Woman confidence: 0.10%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.97%, Woman confidence: 0.08%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Man confidence: 99.97%, Woman confidence: 0.06%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.89%, Woman confidence: 0.16%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.89%, Woman confidence: 0.16%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Man confidence: 99.72%, Woman confidence: 0.42%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.89%, Woman confidence: 0.16%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Man confidence: 99.83%, Woman confidence: 0.23%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.46%, Woman confidence: 0.86%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Man confidence: 99.54%, Woman confidence: 0.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.80%, Woman confidence: 0.26%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 99.90%, Woman confidence: 0.14%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Man confidence: 99.85%, Woman confidence: 0.19%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 99.80%, Woman confidence: 0.26%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.84%, Woman confidence: 0.20%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.88%, Woman confidence: 0.15%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.91%, Woman confidence: 0.12%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.89%, Woman confidence: 0.15%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 99.76%, Woman confidence: 0.32%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Man confidence: 99.78%, Woman confidence: 0.29%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Man confidence: 99.73%, Woman confidence: 0.37%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Man confidence: 99.81%, Woman confidence: 0.25%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.73%, Woman confidence: 0.36%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.75%, Woman confidence: 0.33%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.86%, Woman confidence: 0.20%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.86%, Woman confidence: 0.20%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.72%, Woman confidence: 0.38%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.87%, Woman confidence: 0.18%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.86%, Woman confidence: 0.18%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.61%, Woman confidence: 0.49%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Man confidence: 99.62%, Woman confidence: 0.48%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.72%, Woman confidence: 0.35%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.78%, Woman confidence: 0.27%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.87%, Woman confidence: 0.18%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Man confidence: 99.92%, Woman confidence: 0.12%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 99.97%, Woman confidence: 0.04%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.94%, Woman confidence: 0.08%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.78%, Woman confidence: 0.25%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.79%, Woman confidence: 0.24%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.85%, Woman confidence: 0.17%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.91%, Woman confidence: 0.12%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.93%, Woman confidence: 0.10%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Man confidence: 99.93%, Woman confidence: 0.11%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.94%, Woman confidence: 0.09%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.96%, Woman confidence: 0.07%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.94%, Woman confidence: 0.09%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.96%, Woman confidence: 0.06%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Man confidence: 99.95%, Woman confidence: 0.08%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.93%, Woman confidence: 0.10%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.94%, Woman confidence: 0.08%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.93%, Woman confidence: 0.12%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.93%, Woman confidence: 0.12%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.93%, Woman confidence: 0.14%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Man confidence: 99.89%, Woman confidence: 0.19%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.92%, Woman confidence: 0.14%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.95%, Woman confidence: 0.09%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.97%, Woman confidence: 0.06%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Man confidence: 99.98%, Woman confidence: 0.04%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Man confidence: 99.98%, Woman confidence: 0.04%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.96%, Woman confidence: 0.07%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Man confidence: 99.97%, Woman confidence: 0.05%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.97%, Woman confidence: 0.06%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.97%, Woman confidence: 0.05%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.94%, Woman confidence: 0.10%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.88%, Woman confidence: 0.18%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.94%, Woman confidence: 0.10%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Man confidence: 99.80%, Woman confidence: 0.27%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Man confidence: 99.03%, Woman confidence: 1.20%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 98.55%, Woman confidence: 1.71%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 98.90%, Woman confidence: 1.31%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.06%, Woman confidence: 1.19%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Man confidence: 95.04%, Woman confidence: 5.04%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 96.90%, Woman confidence: 3.30%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Man confidence: 97.11%, Woman confidence: 3.16%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Man confidence: 98.07%, Woman confidence: 2.06%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Man confidence: 98.25%, Woman confidence: 2.11%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Man confidence: 97.51%, Woman confidence: 3.03%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 93.60%, Woman confidence: 8.01%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Man confidence: 92.25%, Woman confidence: 9.19%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 90.79%, Woman confidence: 11.16%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Man confidence: 91.02%, Woman confidence: 10.81%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Man confidence: 89.34%, Woman confidence: 12.50%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Man confidence: 79.29%, Woman confidence: 23.41%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Man confidence: 73.11%, Woman confidence: 30.26%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Man confidence: 99.91%, Woman confidence: 0.14%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.91%, Woman confidence: 0.14%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.91%, Woman confidence: 0.15%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.71%, Woman confidence: 0.45%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Man confidence: 99.71%, Woman confidence: 0.43%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 99.90%, Woman confidence: 0.16%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 97.03%, Woman confidence: 4.06%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Man confidence: 98.10%, Woman confidence: 2.75%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 96.43%, Woman confidence: 4.53%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 98.12%, Woman confidence: 2.63%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 98.66%, Woman confidence: 1.97%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 98.88%, Woman confidence: 1.79%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 98.95%, Woman confidence: 1.72%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 99.06%, Woman confidence: 1.50%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 98.53%, Woman confidence: 2.23%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 98.70%, Woman confidence: 1.71%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 99.51%, Woman confidence: 0.72%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.36%, Woman confidence: 0.89%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.25%, Woman confidence: 1.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 97.75%, Woman confidence: 3.10%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 96.98%, Woman confidence: 3.93%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Man confidence: 94.82%, Woman confidence: 6.40%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 97.69%, Woman confidence: 3.28%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 97.55%, Woman confidence: 3.47%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Man confidence: 97.69%, Woman confidence: 3.19%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 97.46%, Woman confidence: 3.53%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 97.52%, Woman confidence: 3.39%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 95.70%, Woman confidence: 5.09%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 96.09%, Woman confidence: 4.75%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 96.13%, Woman confidence: 4.86%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 94.67%, Woman confidence: 6.52%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 98.69%, Woman confidence: 2.13%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Man confidence: 99.90%, Woman confidence: 0.16%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Man confidence: 99.79%, Woman confidence: 0.32%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Man confidence: 99.81%, Woman confidence: 0.30%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Man confidence: 99.57%, Woman confidence: 0.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 98.60%, Woman confidence: 1.79%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Man confidence: 99.69%, Woman confidence: 0.38%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.81%, Woman confidence: 0.24%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Man confidence: 99.85%, Woman confidence: 0.20%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.84%, Woman confidence: 0.21%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.79%, Woman confidence: 0.28%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.81%, Woman confidence: 0.23%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.13%, Woman confidence: 0.97%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Man confidence: 99.45%, Woman confidence: 0.63%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 99.51%, Woman confidence: 0.59%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Man confidence: 99.29%, Woman confidence: 0.87%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Man confidence: 99.42%, Woman confidence: 0.71%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Man confidence: 96.41%, Woman confidence: 4.43%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 96.77%, Woman confidence: 3.97%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Man confidence: 98.16%, Woman confidence: 2.24%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 98.69%, Woman confidence: 1.53%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 98.68%, Woman confidence: 1.57%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Man confidence: 96.33%, Woman confidence: 4.40%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Man confidence: 96.84%, Woman confidence: 3.94%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 97.26%, Woman confidence: 3.39%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 96.92%, Woman confidence: 3.83%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 95.37%, Woman confidence: 5.63%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Man confidence: 96.36%, Woman confidence: 4.53%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 95.45%, Woman confidence: 5.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 97.02%, Woman confidence: 3.66%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Man confidence: 97.83%, Woman confidence: 2.79%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 98.40%, Woman confidence: 2.03%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 98.41%, Woman confidence: 2.06%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 98.78%, Woman confidence: 1.56%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.50%, Woman confidence: 0.64%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.70%, Woman confidence: 0.40%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.92%, Woman confidence: 0.10%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.89%, Woman confidence: 0.14%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Man confidence: 99.97%, Woman confidence: 0.04%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.92%, Woman confidence: 0.13%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.93%, Woman confidence: 0.11%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Man confidence: 99.93%, Woman confidence: 0.10%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Man confidence: 99.97%, Woman confidence: 0.05%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Man confidence: 99.97%, Woman confidence: 0.05%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Man confidence: 99.96%, Woman confidence: 0.06%
